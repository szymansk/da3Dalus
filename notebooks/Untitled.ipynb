# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from cadquery import Workplane
from cadq_server import cq_helper

import cadquery as cq
from jupyter_cadquery.cadquery import show
from jupyter_cadquery import set_sidecar

set_sidecar("Test", init=True)
objects = []

def show_object(obj):
    global objects
    objects.append(obj)
    show(*objects)

# %%
_airfoil = "../components/airfoils/naca2415.dat"
wing: Workplane = (cq.Workplane('XZ').wing_root_segment(root_airfoil=_airfoil,
                                                        root_chord=200,
                                                        root_dihedral=0,
                                                        root_incidence=3,
                                                        length=500,
                                                        sweep=5,
                                                        sweep_mode="angle",
                                                        tip_chord=100,
                                                        tip_dihedral=4,
                                                        tip_incidence=-2))

# %%
cq.Workplane(wing.vals()[-1]).faces("<Y").vertices().vals()
